# %% [markdown]
# Implemented By Muhammad Hanan Asghar.

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ln -s /content/drive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  caltech256.zip				 object-detection.zip
# 'Colab Notebooks'			 polish-traffic-signs-dataset.zip
#  fine_tuned_model			 traffic-signs-classification.zip
#  labeled-mask-dataset-yolo-darknet.zip	 yolov3
# 'My Drive'				 yolov4

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Mon Jun 21 22:09:06 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P8    33W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15132, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 15132 (delta 26), reused 41 (delta 19), pack-reused 15073
# Receiving objects: 100% (15132/15132), 13.47 MiB | 12.70 MiB/s, done.
# Resolving deltas: 100% (10271/10271), done.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make

# %%
# !cp cfg/yolov3-tiny.cfg cfg/yolov3_tiny_training.cfg

# %%
# !pwd
# %cd /content/darknet
# Out:
# /content/darknet
# /content/darknet

# %%
# !echo -e 'classes= 2\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/classes.names\nbackup = /mydrive/yolov3-tiny' > data/obj.data
# !mkdir data/obj

# %%
# YOLOV3 Tiny Weights
# !wget https://pjreddie.com/media/files/yolov3-tiny.weights
# Out:
# --2021-06-21 22:18:17--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  14.3MB/s    in 2.4s
#
# 2021-06-21 22:18:20 (14.3 MB/s) - ‘yolov3-tiny.weights’ saved [35434956/35434956]

# %%
# !unzip /mydrive/yolov3/dataset.zip -d data/obj

# %%
# Start the training
# !./darknet detector train data/obj.data cfg/yolov3_tiny_training.cfg yolov3-tiny.weights -dont_show -clear
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 132209, rewritten_bbox = 0.181531 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.678438), count: 3, class_loss = 1.020303, iou_loss = 0.229490, total_loss = 1.249792
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.628109), count: 7, class_loss = 1.957578, iou_loss = 1.489579, total_loss = 3.447157
#  total_bbox = 132219, rewritten_bbox = 0.181517 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.854065), count: 3, class_loss = 0.377833, iou_loss = 0.148700, total_loss = 0.526533
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.638479), count: 14, class_loss = 3.831839, iou_loss = 2.286618, total_loss = 6.118457
#  total_bbox = 132236, rewritten_bbox = 0.181494 %
# ...
